# %%
# Import Packages
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from time import sleep

# %%
path="C:chromedriver_win32/chromedriver.exe"
browser=webdriver.Chrome(executable_path=path)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_239988\3792459821.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser=webdriver.Chrome(executable_path=path)

# %%
# url='https://www.google.com/search?q=cloud+kitchen+india&biw=674&bih=656&tbm=lcl&ei=RlyJZPvUJ9OaseMPh7mJ-AU&ved=0ahUKEwj7j5Sij8L_AhVTTWwGHYdcAl8Q4dUDCAk&uact=5&oq=cloud+kitchen+india&gs_lp=Eg1nd3Mtd2l6LWxvY2FsIhNjbG91ZCBraXRjaGVuIGluZGlhMgsQABiABBixAxiDATIFEAAYgAQyBRAAGIAEMgUQABiABDIFEAAYgAQyBhAAGBYYHjIGEAAYFhgeMgYQABgWGB4yBhAAGBYYHjIGEAAYFhgeSO4mUOoNWPcYcAB4AJABAJgBogGgAbAHqgEDMC43uAEDyAEA-AEBwgIKEAAYigUYsQMYQ8ICCBAAGIAEGLEDwgIIEAAYgAQYyQPCAggQABiKBRiSA8ICBxAAGIoFGEOIBgE&sclient=gws-wiz-local#rlfi=hd:;si:;mv:[[23.088173896368783,93.43513708120115],[12.601724234381908,72.64900426870115]]'
browser.get('https://www.startupindia.gov.in/content/sih/en/search.html?roles=Startup&page=24')
# browser.get(url)
browser.maximize_window()

# %%
for i in range(120,121):
    browser.get('https://www.startupindia.gov.in/content/sih/en/search.html?roles=Startup&page='+str(i))
    sleep(5)
    browser.maximize_window()
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    sleep(0.5)
    print(i)

# %%
web_links=[]
name=[]
location=[]

browser.maximize_window()
# browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
sleep(0.5)

main=browser.find_element(By.XPATH,'//div[@id="persona-results"]')
try:
    links=main.find_elements(By.XPATH,'//a[@class="img-wrap"]')
    for i in links: 
          web_links.append(i.get_attribute('href'))
except:
    web_links.append("")
    
try:
    names=main.find_elements(By.XPATH,'//div[@class="events-details"]//h3')
    for i in names: 
          name.append(i.text)

except:
    name.append("")        
        
try:        
    locations=main.find_elements(By.XPATH,'//li[@class="location"]')
    for i in locations: 
          location.append(i.text)
except:
    location.append("")

# %%
df = pd.DataFrame({
        'name':name,
        'website':web_links,
     
        'location':location
    

    })
df.to_csv('30linklink.csv',index=False)

# %%
data=pd.read_csv('30linklink.csv')
len(data)
data['website'][1]
# Out:
# 'https://www.startupindia.gov.in/content/sih/en/profile.Startup.649e5d35e4b0a5524e7b7765.html'

# %%
website=[]
namew=[]
date=[]
loc=[]

for i in range(len(data)):
    browser.get(data['website'][i])
    sleep(2)
    
    try:
        names=browser.find_element(By.XPATH,'//div[@class="company-name"]//p')
        namew.append(names.text)
    except:
        namew.append("")  
        
    try:
        websites=browser.find_element(By.XPATH,'//div[@class="company-name"]//a[@class="website"]')
        website.append(websites.get_attribute('href'))
    except:
        website.append("")  
        
    try:
        dates=browser.find_element(By.XPATH,'//span[@class="orglevel active-since"]//strong')
        date.append(dates.text)
    except:
        date.append("") 
    loc.append(data['location'][i])

# %%
len(website)
# Out:
# 62

# %%
df = pd.DataFrame({
        'name':namew,
        'website':website,
        'date':date,
        'location':loc
    

    })
df.to_csv('startupnic30.csv',index=False)

# %%
df
# Out:
#                                                 Name Phone1 Phone2 Phone3  \
# 0                 TAVAST UDYOG INDIA PRIVATE LIMITED    nan    nan    nan
# 1   L.N.T.T MANUFACTURING INDUSTRIES PRIVATE LIMITED    nan    nan    nan
# 2                   Bridgeway Power Services pvt ltd    nan    nan    nan
# 3                           Balaji Perfect Solutions     []     []     []
# 4                                     Takao Fujiwara    nan    nan    nan
# ..                                               ...    ...    ...    ...
# 57                            NEELA SONS ENTERPRISES    nan    nan    nan
# 58                                     LEELA TRADERS    nan    nan    nan
# 59            SAFFRON TASTY EATABLES PRIVATE LIMITED    nan    nan    nan
# 60                       AJAYA KUMAS PRIVATE LIMITED    nan    nan    nan
# 61                                 CoxNation Designs    nan    nan    nan
#
#    Phone4 Phone5 Phone6 email                     Website linkedin Facebook  \
# ...

# %% [markdown]
# browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
import pandas as pd
data=pd.read_csv('startupnic30.csv')
len(data['website'])
# data['website']
data
# Out:
#                                                  name  \
# 0                            Balaji Perfect Solutions
# 1                     RRGUARDUS INDIA PRIVATE LIMITED
# 2                   BEVERAGES IMBIBED PRIVATE LIMITED
# 3                                              Ewilco
# 4         FOOKRI SMART PLAY SOLUTIONS PRIVATE LIMITED
# 5                                         Baenuts LLP
# 6                       dAcore innovational Pvt. Ltd.
# 7                  ESIXM ECO-DREDGING PRIVATE LIMITED
# 8                                               Proft
# 9            ANALYTICSVERSE SOLUTIONS PRIVATE LIMITED
# 10                      salvage symbiotic (vehiscrap)
# 11     HEALTETHER HEALTHCARE SERVICES PRIVATE LIMITED
# 12                                          Gohearing
# 13                 BUYQUA MARKETPLACE PRIVATE LIMITED
# 14                 RINI POWDER PAINTS PRIVATE LIMITED
# 15            AETHER TECHNO SOLUTIONS PRIVATE LIMITED
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re
from bs4 import BeautifulSoup as bs
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys 
from selenium.webdriver.chrome.service import Service
from time import sleep
import re
import requests
email=[]
phone1=[]
phone2=[]
phone3=[]
phone4=[]
phone5=[]
phone6=[]
linkedin=[]
facebook=[]
name=[]
# name_or=[]
web=[]
loc=[]
# Fetch the HTML content of the web page
# url = 'https://www.comptechdigital.in/'

for url in range(len(data)):
   
    try:
        # response=requests.get('https://digitcure.com/')
        response = requests.get(data['website'][url])
        # response = requests.get(data['facebook1'][url])
        html_content = response.text
        soup = BeautifulSoup(html_content, 'html.parser')
        name.append(data['name'][url])
        web.append(data['website'][url])
        loc.append(data['location'][url])
        
        
        # Scrape email addresses
        email_pattern = r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b"
        email_matches = re.findall(email_pattern, html_content)
        email.append(email_matches)

        # Scrape phone numbers
        phone_pattern = r"\+\d\s\d{3}\s\d{3}\s\d{4}"
        phone_matches = re.findall(phone_pattern, html_content)
        phone1.append(phone_matches)
        # # Print scraped phone numbers
        # for phone_number in phone_matches:
        #     phone1.append(phone_number)



        phone_pattern = r"\d{3}-\d{3}-\d{4}"
        phone_matches = re.findall(phone_pattern, html_content)
        phone2.append(phone_matches)

        cleaned_content = re.sub(r'\s|-', '', html_content)

        # Scrape phone numbers starting with "+91"
        phone_pattern = r"\+91\d{10}"
        phone_matches = re.findall(phone_pattern, cleaned_content)
        phone3.append(phone_matches)


        modified_text = re.sub(r'[\s-]', '', html_content)

        # Scrape phone numbers starting with "+"
        phone_pattern = r"\+\d+"
        phone_matches = re.findall(phone_pattern, modified_text)
        phone4.append(phone_matches)

        phone_pattern = r"\+91\s\d{3}\s\d{3}\s\d{4}"
        phone_matches = re.findall(phone_pattern, html_content)
        phone5.append(phone_matches)


        facebook_pattern = r"https?://(?:www\.)?facebook\.com/[a-zA-Z0-9_\-/]+"
        facebook_links = re.findall(facebook_pattern, html_content)
        facebook.append(facebook_links)

  
        phone_pattern = r"\+91-\d{10}"
        phone_matches = re.findall(phone_pattern, html_content)
        phone6.append(phone_matches)
        

        try:
            linkedin_links = soup.find_all('a', href=re.compile(r'linkedin\.com/in/'))

            # Extract the href attribute value from the anchor tags
            linkedin_profiles = [link['href'] for link in linkedin_links]

            linkedin.append(linkedin_profiles)
        except:
            linkedin.append('nan')


        
    except:
        print('site not working')
        print(data['website'][url])
        email.append('nan')
        phone1.append('nan')
        phone2.append('nan')
        phone3.append('nan')
        phone4.append('nan')
        phone5.append('nan')
        phone6.append('nan')
        linkedin.append('nan')
        facebook.append('nan')
        # name.append('nan')
        name.append(data['name'][url])
        web.append(data['website'][url])
        loc.append(data['location'][url])

        
        
        



df=pd.DataFrame({
    'Name':name,
    # 'Name_org':name_or,
  
     'Phone1':phone1,
    'Phone2':phone2,
    'Phone3':phone3,
    'Phone4':phone4,
    'Phone5':phone5,
    'Phone6':phone6,
    'email':email,
    'Website':web,
    'linkedin':linkedin,
    'Facebook':facebook,
    'Location':loc
    # 'web':web
    # 'doamin_list':doamin_list
    
               })

df.to_csv("domain_facebook_startup30.csv",index=False)
# Out:
# site not working
# http://not/
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[29], line 146
#     118         loc.append(data['location'][url])
#     126 df=pd.DataFrame({
#     127     'Name':name,
#     128     # 'Name_org':name_or,
#    (...)
#     143
#     144                })
# --> 146 df.to_csv("domain_facebook_startup30.csv",index=False)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
df.to_csv("domain_facebook_startup30.csv",index=False)

# %%
df

# %%
input_search_Category=browser.find_element(By.XPATH,'//textarea[@class="gLFyf"]')
search_button=browser.find_element(By.XPATH,'//div[@class="FPdoLc lJ9FBc"]//center//input[@class="gNO89b"]')
Keyword='cloud computing pune'
input_search_Category.send_keys(Keyword)
sleep(1)

sleep(2)

# %%
browser.find_element(By.XPATH,'//div[@jsmodel="sj77Re P9Kqfe"]').click()

# %% [markdown]
# search_button.click()

# %%
more_button=browser.find_element(By.XPATH,'//a[@class="jRKCUd"]')
more_button.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 more_button=browser.find_element(By.XPATH,'//a[@class="jRKCUd"]')
#       2 more_button.click()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     828     by = By.CSS_SELECTOR
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# ...

# %%
name=[]
address=[]
phone=[]
category=[]
star=[]
website=[]
count=1
for j in range(1,20):
    for i in range(1,21):
        sleep(3)
        browser.find_element(By.XPATH,f'(//span[@class="OSrXXb"])[{i}]').click()
        try:
            name.append(browser.find_element(By.XPATH,'//div[@class="Ftghae iirjIb DaSCDf GUV4E"]//h2').text)
        except:
            name.append('nan')

        try:
            star.append(browser.find_element(By.XPATH,'//div[@class="Ob2kfd"]//div//span[@class="yi40Hd YrbPuc"]').text)
        except:
            star.append('nan')


        try:
            address.append(browser.find_element(By.XPATH,'//div[@class="zloOqf PZPZlf"]//span[@class="LrzXr"]').text)
        except:
            address.append('nan') 

        try:
            phone.append(browser.find_element(By.XPATH,'//a[@data-dtype="d3ph"]//span').text)
        except:
            phone.append('nan') 
            
        try:
            category.append(browser.find_element(By.XPATH,'//span[@class="YhemCb"]').text)
        except:
            category.append('nan') 
            
        try:
            website.append(browser.find_element(By.XPATH,'//a[@class="dHS6jb"]').get_attribute('href'))
        except:
            website.append('nan')

        # data.find_element(By.XPATH,'//div[@class="QU77pf"]').click()
    
    browser.find_element(By.XPATH,'//a[@id="pnnext"]').click()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[14], line 11
#       9 for i in range(1,21):
#      10     sleep(3)
# ---> 11     browser.find_element(By.XPATH,f'(//span[@class="OSrXXb"])[{i}]').click()
#      12     try:
#      13         name.append(browser.find_element(By.XPATH,'//div[@class="Ftghae iirjIb DaSCDf GUV4E"]//h2').text)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:94, in WebElement.click(self)
#      92 def click(self) -> None:
#      93     """Clicks the element."""
# ---> 94     self._execute(Command.CLICK_ELEMENT)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:403, in WebElement._execute(self, command, params)
#     401     params = {}
#     402 params["id"] = self._id
# --> 403 return self._parent.execute(command, params)
#
# ...

# %%
df = pd.DataFrame({
        'Name':name,
        'Address':address,
        'Phone':phone,
        'Category':category,
    'star':star,
    'Website':website
    

    })
df.to_csv('cloud computing pune .csv',index=False)

# %%
browser.implicitly_wait(5)
keepScrolling=True
while(keepScrolling):
    main=browser.find_element(By.XPATH,'//div[@role="feed"]')
    browser.execute_script('arguments[0].scrollBy(0, document.body.scrollHeight);', main)
    sleep(0.5)
    html =browser.find_element(By.TAG_NAME, "html").get_attribute('outerHTML')
    if(html.find("You've reached the end of the list.")!=-1):
        keepScrolling=False

    # -----------------------------------------------------------------------------#
    
c=0
div=[] 
div_link=[]
for i in (browser.find_elements(By.XPATH,'//a[@class="hfpxzc"]')):
    div_link.append(i.get_attribute('href'))
for i in (browser.find_elements(By.XPATH,'//div[@class="qBF1Pd fontHeadlineSmall "]')):
    div.append(i.text)
    c+=1      
print("total",c)
    # -----------------------------------------------------------------------------#
name=[]
address=[]
phone=[]
category=[]
city=[]
state=[]
country=[]
website=[]
s=0
for url in div_link:
    browser.get(url)
        
        #scroll
    sleep(0.2)
    keepScrolling=True
    while(keepScrolling):
        main=browser.find_element(By.XPATH,'//div[@class="m6QErb "]')
        browser.execute_script('arguments[0].scrollBy(0, document.body.scrollHeight);', main)
        html =browser.find_element(By.XPATH,'//span[@class="GMtm7c fontTitleSmall"]').text
        if(html=="Suggest an edit"):
            keepScrolling=False
                
    #phone
    try:
        for i in browser.find_elements(By.XPATH,'//div[@class="rogA2c "]//div[@class="Io6YTe fontBodyMedium "]'):
            ph=' '
            k=i.text
            if k.startswith('+') or k.startswith('(') or (k.replace(' ','')).isdigit(): 
                ph=k
                break
            
        phone.append(ph)
    except:
        phone.append("nan")

    # name
    try:
        name.append(browser.find_element(By.XPATH,'//h1[@class="DUwDvf fontHeadlineLarge"]').text)
    except:
        name.append('nan')


        #website    
    try:
        website.append(browser.find_element(By.XPATH,'//div[@class="rogA2c ITvuef"]//div[@class="Io6YTe fontBodyMedium "]').text)
    except:
        website.append('nan')


    # category
    try:
        category.append(browser.find_element(By.XPATH,'//button[@class="DkEaL "]').text)
    except:
        category.append('nan')

    sleep(0.1)

       
        # Address    
    try:
        m=browser.find_element(By.XPATH,'//div[@class="rogA2c "]//div[@class="Io6YTe fontBodyMedium "]').text
        if ("+" in m) or "(" in m or (m.replace(' ','')).isdigit() :
            address.append('nan')
        else:
            address.append(m)
    except:
        address.append('nan')
        


    
       
    print("Scrape No.",s+1)
    s+=1
# Out:
# total 0

# %%
len(LinkedIn)
# # k=LinkedIn_link
# for i in LinkedIn_link:
#     k.append(i)
# Out:
# 290

# %%
for link in LinkedIn_link:
    browser.get(link)
    sleep(3)

# %%
url=product_link[0]
browser.get(url)
browser.maximize_window()
for element in browser.find_elements(By.XPATH,'//div[@class="pb-5"]//div[@class="col-md-12"]') :
    i=element.find_element(By.XPATH,'(//div[@id="result1"]//div//a)[1]')
    print(i.get_attribute('href'))
# Out:
# http://www.kolhapurbusiness.com/companyinfo/creative-sales-and-services-kolhapur-1977.html
# http://www.kolhapurbusiness.com/companyinfo/creative-sales-and-services-kolhapur-1977.html
# http://www.kolhapurbusiness.com/companyinfo/creative-sales-and-services-kolhapur-1977.html
# http://www.kolhapurbusiness.com/companyinfo/creative-sales-and-services-kolhapur-1977.html
# http://www.kolhapurbusiness.com/companyinfo/creative-sales-and-services-kolhapur-1977.html
# http://www.kolhapurbusiness.com/companyinfo/creative-sales-and-services-kolhapur-1977.html
# http://www.kolhapurbusiness.com/companyinfo/creative-sales-and-services-kolhapur-1977.html
# http://www.kolhapurbusiness.com/companyinfo/creative-sales-and-services-kolhapur-1977.html
# http://www.kolhapurbusiness.com/companyinfo/creative-sales-and-services-kolhapur-1977.html
# http://www.kolhapurbusiness.com/companyinfo/creative-sales-and-services-kolhapur-1977.html

# %%
for i in element.find_elements(By.XPATH,'(//div[@id="result1"]//div//a)[1]'):
    print(i.get_attribute('href'))
# Out:
# http://www.kolhapurbusiness.com/companyinfo/creative-sales-and-services-kolhapur-1977.html
