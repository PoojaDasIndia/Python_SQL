# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
name=[]
for i in range(50):
    url=f'https://www.shopify.com/tools/slogan-maker/show/qTVHl6bL990=--I6s3c1ZbjKAUb4UJ--sAuhxwHzFnxEfbaeOOs4mA==.html?page={str(i)}'
    req = requests.get(url)
    soup = bs(req.content, 'html.parser')
    for i in soup.find_all('div',class_="grid-container-flex__item"):
        name.append(i.text.strip())

# %%
name=[]
for i in soup.find_all('div',class_="grid-container-flex__item"):
     name.append(i.text.strip())

# %%
len(name)
# name
# Out:
# 450

# %%
url='https://businesschamberqld.com.au/membership/member-directory/browse?start=0'

# %%
import requests
from bs4 import BeautifulSoup
import re
from bs4 import BeautifulSoup as bs
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys 
from selenium.webdriver.chrome.service import Service
from time import sleep

# %%
path="C:chromedriver_win32/chromedriver.exe"
driver=webdriver.Chrome(executable_path=path)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_348520\3327342603.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path=path)

# %%
name=[]
try:
    for i in range(22):
        # driver.get('https://www.google.com/search?q=%22Powered+and+secured+by+Wix%22&sxsrf=APwXEdfdXSRMOKV1v1YukJsRZoecgYVNqw:1687787474461&source=lnt&tbs=qdr:d&sa=X&ved=2ahUKEwit9PumiuH_AhWXyjgGHWjHBGQQpwV6BAgBEAg&biw=1280&bih=609&dpr=1.5#ip=1')
        driver.get(f'https://www.shopify.com/tools/slogan-maker/show/qTVHl6bL990=--I6s3c1ZbjKAUb4UJ--sAuhxwHzFnxEfbaeOOs4mA==.html?page={str(i)}')
        sleep(1)

        names = driver.find_elements(By.XPATH,'//div[@class="grid-container-flex__item"]//button') 
        for i in names:
            name.append(i.text)
            print(i.text)
               
except:
    print('error')
# Out:
# Pooja will be for you what you want it to be.
# You Press the Pooja, We Do the Rest.
# Pooja, fun for the whole family.
# the science of Pooja.
# I'm a Secret Pooja Drinker.
# From Our Pooja to Yours.
# Washing Machines Live Longer With Pooja.
# Pooja is scrumdelious!
# I Learned It By Watching Pooja!
# Pooja built to perfection.
# Only Pooja Has The Answer.
# Let the Pooja Begin.
# Pooja 100% guaranteed or your money back.
# Beware of Expensive Pooja.
# Get Pooja, forget the rest.
# Pooja, your specialist.
# I fall for Pooja.
# To Pooja, or not to Pooja.
# Run For The Pooja.
# My way is Pooja.
# The Pooja look.
# Don't Hold Pooja Back.
# Snap! Crackle! Pooja!
# What is Pooja?
# Ho Ho Ho, Green Pooja.
# You Too Can Have A Pooja Like Mine.
# When The Going Gets Tough, The Tough Get Pooja.
# Pooja gives that warm feeling.
# Full Of Eastern Pooja.
# Pooja, so what!
# I'm Cuckoo For Pooja.
# Better Ingredients, Better Pooja.
# Can you feel it? Pooja.
# ...

# %%
len(name)
# Out:
# 773

# %%
df=pd.DataFrame({
    'Name':name})
df.to_csv("sologan.csv",index=False)

# %%
req = requests.get(url)
print(req)
"It's a Lot Less {Pooja} Than a Hover."
# Out:
# <Response [200]>

# %%
soup = bs(req.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en-AU">
# <head>
# <base href="https://businesschamberqld.com.au/"/><!--[if lte IE 6]></base><![endif]-->
# <title>Business Directory » Business Chamber Queensland</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <meta content="Silverstripe CMS 4.12" name="generator">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="Search Business Chamber Queensland’s Member directory. Browse or locate near you your future partnerships, suppliers or contractors." name="description"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:ital,wght@0,400;0,700;1,400;1,700&amp;family=Playfair+Display:ital,wght@0,500;1,500&amp;display=swap" rel="stylesheet"/>
# ...
